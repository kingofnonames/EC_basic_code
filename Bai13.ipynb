# %% [markdown]
# ## Bài 13: Harmony Search (HS)

# %% [markdown]
# ### Cài đặt HS cho bài toán TSP

# %%
import numpy as np
import random
random.seed(42)

# %%
def distance_matrix(coords):
    n = len(coords)
    dmat = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            dmat[i, j] = dmat[j, i] = np.linalg.norm(
                np.array(coords[i]) - np.array(coords[j]))
    return dmat

def tour_length(tour, dmat):
    return np.sum(dmat[tour[i], tour[(i + 1) % len(tour)]] for i in range(len(tour)))

def initialize_harmony_memory(hm_size, n_cities, dmat):
    HM = []
    for _ in range(hm_size):
        tour = list(range(n_cities))
        random.shuffle(tour)
        HM.append((tour, tour_length(tour, dmat)))
    HM.sort(key=lambda x: x[1])
    return HM

def generate_new_harmony(HM, n_cities, HMCR, PAR):
    best_tours = [t[0] for t in HM]
    n_harmony = random.choice(best_tours)
    new_tour = n_harmony.copy()
    if random.random() > HMCR:
        random.shuffle(new_tour)
    if random.random() < PAR:
        i, j = random.sample(range(n_cities), 2)
        new_tour[i], new_tour[j] = new_tour[j], new_tour[i]
    return new_tour

def harmony_search_tsp(dmat, hm_size=20, max_iter=1000, HMCR=0.9, PAR=0.3):
    n_cities = len(dmat)
    HM = initialize_harmony_memory(hm_size, n_cities, dmat)
    for it in range(max_iter):
        new_tour = generate_new_harmony(HM, n_cities, HMCR, PAR)
        new_len = tour_length(new_tour, dmat)
        if new_len < HM[-1][1]:
            HM[-1] = (new_tour, new_len)
            HM.sort(key=lambda x: x[1])
        if it % 100 == 0:
            print(f"Iter {it}, Best length = {HM[0][1]:.2f}")
    return HM[0]

# %%
coords = [(random.random() * 100, random.random() * 100) for _ in range(30)]
dmat = distance_matrix(coords)
best_tour, best_len = harmony_search_tsp(dmat, max_iter=100000)
print("Best tour:", best_tour)
print("Best length:", best_len)
# Out:
# C:\Users\quoca\AppData\Local\Temp\ipykernel_2176\4261921197.py:11: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return np.sum(dmat[tour[i], tour[(i + 1) % len(tour)]] for i in range(len(tour)))
# Iter 0, Best length = 1234.24
# Iter 100, Best length = 1104.91
# Iter 200, Best length = 995.20
# Iter 300, Best length = 948.63
# Iter 400, Best length = 906.68
# Iter 500, Best length = 860.22
# Iter 600, Best length = 852.51
# Iter 700, Best length = 844.59
# Iter 800, Best length = 839.84
# Iter 900, Best length = 810.79
# Iter 1000, Best length = 724.12
# Iter 1100, Best length = 696.12
# Iter 1200, Best length = 683.97
# Iter 1300, Best length = 676.71
# Iter 1400, Best length = 656.30
# Iter 1500, Best length = 617.17
# Iter 1600, Best length = 613.50
# Iter 1700, Best length = 613.50
# Iter 1800, Best length = 606.13
# Iter 1900, Best length = 606.13
# Iter 2000, Best length = 606.13
# Iter 2100, Best length = 606.13
# Iter 2200, Best length = 606.13
# Iter 2300, Best length = 606.13
# Iter 2400, Best length = 594.78
# Iter 2500, Best length = 582.72
# Iter 2600, Best length = 582.72
# Iter 2700, Best length = 582.72
# Iter 2800, Best length = 582.33
# Iter 2900, Best length = 582.33
# Iter 3000, Best length = 582.33
# Iter 3100, Best length = 582.33
# Iter 3200, Best length = 582.33
# Iter 3300, Best length = 582.33
# Iter 3400, Best length = 582.33
# Iter 3500, Best length = 582.33
# Iter 3600, Best length = 582.33
# Iter 3700, Best length = 560.81
# Iter 3800, Best length = 560.81
# Iter 3900, Best length = 560.81
# Iter 4000, Best length = 560.81
# Iter 4100, Best length = 560.81
# Iter 4200, Best length = 560.81
# Iter 4300, Best length = 560.81
# Iter 4400, Best length = 559.68
# Iter 4500, Best length = 551.19
# Iter 4600, Best length = 550.06
# Iter 4700, Best length = 550.06
# Iter 4800, Best length = 550.06
# Iter 4900, Best length = 550.06
# Iter 5000, Best length = 550.06
# Iter 5100, Best length = 550.06
# Iter 5200, Best length = 550.06
# Iter 5300, Best length = 550.06
# Iter 5400, Best length = 550.06
# Iter 5500, Best length = 550.06
# Iter 5600, Best length = 550.06
# Iter 5700, Best length = 549.55
# Iter 5800, Best length = 549.55
# Iter 5900, Best length = 549.55
# Iter 6000, Best length = 549.55
# Iter 6100, Best length = 549.55
# Iter 6200, Best length = 549.55
# Iter 6300, Best length = 549.55
# Iter 6400, Best length = 549.55
# Iter 6500, Best length = 549.55
# Iter 6600, Best length = 549.55
# Iter 6700, Best length = 549.55
# Iter 6800, Best length = 548.43
# Iter 6900, Best length = 548.43
# Iter 7000, Best length = 548.43
# Iter 7100, Best length = 548.43
# Iter 7200, Best length = 548.43
# Iter 7300, Best length = 548.43
# Iter 7400, Best length = 548.43
# Iter 7500, Best length = 548.43
# Iter 7600, Best length = 548.43
# Iter 7700, Best length = 548.43
# Iter 7800, Best length = 536.02
# Iter 7900, Best length = 536.02
# Iter 8000, Best length = 536.02
# Iter 8100, Best length = 536.02
# Iter 8200, Best length = 536.02
# Iter 8300, Best length = 536.02
# Iter 8400, Best length = 536.02
# Iter 8500, Best length = 536.02
# Iter 8600, Best length = 536.02
# Iter 8700, Best length = 536.02
# Iter 8800, Best length = 536.02
# Iter 8900, Best length = 536.02
# Iter 9000, Best length = 536.02
# Iter 9100, Best length = 536.02
# Iter 9200, Best length = 536.02
# Iter 9300, Best length = 536.02
# Iter 9400, Best length = 536.02
# Iter 9500, Best length = 536.02
# Iter 9600, Best length = 536.02
# Iter 9700, Best length = 536.02
# Iter 9800, Best length = 536.02
# Iter 9900, Best length = 536.02
# Iter 10000, Best length = 536.02
# Iter 10100, Best length = 536.02
# Iter 10200, Best length = 536.02
# Iter 10300, Best length = 536.02
# Iter 10400, Best length = 536.02
# Iter 10500, Best length = 536.02
# Iter 10600, Best length = 536.02
# Iter 10700, Best length = 536.02
# Iter 10800, Best length = 536.02
# Iter 10900, Best length = 536.02
# Iter 11000, Best length = 536.02
# Iter 11100, Best length = 536.02
# Iter 11200, Best length = 536.02
# Iter 11300, Best length = 536.02
# Iter 11400, Best length = 536.02
# Iter 11500, Best length = 536.02
# Iter 11600, Best length = 536.02
# Iter 11700, Best length = 536.02
# Iter 11800, Best length = 536.02
# Iter 11900, Best length = 536.02
# Iter 12000, Best length = 536.02
# Iter 12100, Best length = 536.02
# Iter 12200, Best length = 536.02
# Iter 12300, Best length = 536.02
# Iter 12400, Best length = 536.02
# Iter 12500, Best length = 536.02
# Iter 12600, Best length = 536.02
# Iter 12700, Best length = 536.02
# Iter 12800, Best length = 536.02
# Iter 12900, Best length = 536.02
# Iter 13000, Best length = 536.02
# Iter 13100, Best length = 536.02
# Iter 13200, Best length = 536.02
# Iter 13300, Best length = 536.02
# Iter 13400, Best length = 536.02
# Iter 13500, Best length = 536.02
# Iter 13600, Best length = 536.02
# Iter 13700, Best length = 536.02
# Iter 13800, Best length = 536.02
# Iter 13900, Best length = 536.02
# Iter 14000, Best length = 536.02
# Iter 14100, Best length = 536.02
# Iter 14200, Best length = 536.02
# Iter 14300, Best length = 536.02
# Iter 14400, Best length = 536.02
# Iter 14500, Best length = 536.02
# Iter 14600, Best length = 536.02
# Iter 14700, Best length = 536.02
# Iter 14800, Best length = 536.02
# Iter 14900, Best length = 536.02
# Iter 15000, Best length = 536.02
# Iter 15100, Best length = 536.02
# Iter 15200, Best length = 536.02
# Iter 15300, Best length = 536.02
# Iter 15400, Best length = 536.02
# Iter 15500, Best length = 536.02
# Iter 15600, Best length = 536.02
# Iter 15700, Best length = 536.02
# Iter 15800, Best length = 536.02
# Iter 15900, Best length = 536.02
# Iter 16000, Best length = 536.02
# Iter 16100, Best length = 536.02
# Iter 16200, Best length = 536.02
# Iter 16300, Best length = 536.02
# Iter 16400, Best length = 536.02
# Iter 16500, Best length = 536.02
# Iter 16600, Best length = 536.02
# Iter 16700, Best length = 536.02
# Iter 16800, Best length = 536.02
# Iter 16900, Best length = 536.02
# Iter 17000, Best length = 536.02
# Iter 17100, Best length = 536.02
# Iter 17200, Best length = 536.02
# Iter 17300, Best length = 536.02
# Iter 17400, Best length = 536.02
# Iter 17500, Best length = 536.02
# Iter 17600, Best length = 536.02
# Iter 17700, Best length = 536.02
# Iter 17800, Best length = 536.02
# Iter 17900, Best length = 536.02
# Iter 18000, Best length = 536.02
# Iter 18100, Best length = 536.02
# Iter 18200, Best length = 536.02
# Iter 18300, Best length = 536.02
# Iter 18400, Best length = 536.02
# Iter 18500, Best length = 536.02
# Iter 18600, Best length = 536.02
# Iter 18700, Best length = 536.02
# Iter 18800, Best length = 536.02
# Iter 18900, Best length = 536.02
# Iter 19000, Best length = 536.02
# Iter 19100, Best length = 536.02
# Iter 19200, Best length = 536.02
# Iter 19300, Best length = 536.02
# Iter 19400, Best length = 536.02
# Iter 19500, Best length = 536.02
# Iter 19600, Best length = 536.02
# Iter 19700, Best length = 536.02
# Iter 19800, Best length = 536.02
# Iter 19900, Best length = 536.02
# Iter 20000, Best length = 536.02
# Iter 20100, Best length = 536.02
# Iter 20200, Best length = 536.02
# Iter 20300, Best length = 536.02
# Iter 20400, Best length = 536.02
# Iter 20500, Best length = 536.02
# Iter 20600, Best length = 536.02
# Iter 20700, Best length = 536.02
# Iter 20800, Best length = 536.02
# Iter 20900, Best length = 536.02
# Iter 21000, Best length = 536.02
# Iter 21100, Best length = 536.02
# Iter 21200, Best length = 536.02
# Iter 21300, Best length = 536.02
# Iter 21400, Best length = 536.02
# Iter 21500, Best length = 536.02
# Iter 21600, Best length = 536.02
# Iter 21700, Best length = 536.02
# Iter 21800, Best length = 536.02
# Iter 21900, Best length = 536.02
# Iter 22000, Best length = 536.02
# Iter 22100, Best length = 536.02
# Iter 22200, Best length = 536.02
# Iter 22300, Best length = 536.02
# Iter 22400, Best length = 536.02
# Iter 22500, Best length = 536.02
# Iter 22600, Best length = 536.02
# Iter 22700, Best length = 536.02
# Iter 22800, Best length = 536.02
# Iter 22900, Best length = 536.02
# Iter 23000, Best length = 536.02
# Iter 23100, Best length = 536.02
# Iter 23200, Best length = 536.02
# Iter 23300, Best length = 536.02
# Iter 23400, Best length = 536.02
# Iter 23500, Best length = 536.02
# Iter 23600, Best length = 536.02
# Iter 23700, Best length = 536.02
# Iter 23800, Best length = 536.02
# Iter 23900, Best length = 536.02
# Iter 24000, Best length = 536.02
# Iter 24100, Best length = 536.02
# Iter 24200, Best length = 536.02
# Iter 24300, Best length = 536.02
# Iter 24400, Best length = 536.02
# Iter 24500, Best length = 536.02
# Iter 24600, Best length = 536.02
# Iter 24700, Best length = 536.02
# Iter 24800, Best length = 536.02
# Iter 24900, Best length = 536.02
# Iter 25000, Best length = 536.02
# Iter 25100, Best length = 536.02
# Iter 25200, Best length = 536.02
# Iter 25300, Best length = 536.02
# Iter 25400, Best length = 536.02
# Iter 25500, Best length = 536.02
# Iter 25600, Best length = 536.02
# Iter 25700, Best length = 536.02
# Iter 25800, Best length = 536.02
# Iter 25900, Best length = 536.02
# Iter 26000, Best length = 536.02
# Iter 26100, Best length = 536.02
# Iter 26200, Best length = 536.02
# Iter 26300, Best length = 536.02
# Iter 26400, Best length = 536.02
# Iter 26500, Best length = 536.02
# Iter 26600, Best length = 536.02
# Iter 26700, Best length = 536.02
# Iter 26800, Best length = 536.02
# Iter 26900, Best length = 536.02
# Iter 27000, Best length = 536.02
# Iter 27100, Best length = 536.02
# Iter 27200, Best length = 536.02
# Iter 27300, Best length = 536.02
# Iter 27400, Best length = 536.02
# Iter 27500, Best length = 536.02
# Iter 27600, Best length = 536.02
# Iter 27700, Best length = 536.02
# Iter 27800, Best length = 536.02
# Iter 27900, Best length = 536.02
# Iter 28000, Best length = 536.02
# Iter 28100, Best length = 536.02
# Iter 28200, Best length = 536.02
# Iter 28300, Best length = 536.02
# Iter 28400, Best length = 536.02
# Iter 28500, Best length = 536.02
# Iter 28600, Best length = 536.02
# Iter 28700, Best length = 536.02
# Iter 28800, Best length = 536.02
# Iter 28900, Best length = 536.02
# Iter 29000, Best length = 536.02
# Iter 29100, Best length = 536.02
# Iter 29200, Best length = 536.02
# Iter 29300, Best length = 536.02
# Iter 29400, Best length = 536.02
# Iter 29500, Best length = 536.02
# Iter 29600, Best length = 536.02
# Iter 29700, Best length = 536.02
# Iter 29800, Best length = 536.02
# Iter 29900, Best length = 536.02
# Iter 30000, Best length = 536.02
# Iter 30100, Best length = 536.02
# Iter 30200, Best length = 536.02
# Iter 30300, Best length = 536.02
# Iter 30400, Best length = 536.02
# Iter 30500, Best length = 536.02
# Iter 30600, Best length = 536.02
# Iter 30700, Best length = 536.02
# Iter 30800, Best length = 536.02
# Iter 30900, Best length = 536.02
# Iter 31000, Best length = 536.02
# Iter 31100, Best length = 536.02
# Iter 31200, Best length = 536.02
# Iter 31300, Best length = 536.02
# Iter 31400, Best length = 536.02
# Iter 31500, Best length = 536.02
# Iter 31600, Best length = 536.02
# Iter 31700, Best length = 536.02
# Iter 31800, Best length = 536.02
# Iter 31900, Best length = 536.02
# Iter 32000, Best length = 536.02
# Iter 32100, Best length = 536.02
# Iter 32200, Best length = 536.02
# Iter 32300, Best length = 536.02
# Iter 32400, Best length = 536.02
# Iter 32500, Best length = 536.02
# Iter 32600, Best length = 536.02
# Iter 32700, Best length = 536.02
# Iter 32800, Best length = 536.02
# Iter 32900, Best length = 536.02
# Iter 33000, Best length = 536.02
# Iter 33100, Best length = 536.02
# Iter 33200, Best length = 536.02
# Iter 33300, Best length = 536.02
# Iter 33400, Best length = 536.02
# Iter 33500, Best length = 536.02
# Iter 33600, Best length = 536.02
# Iter 33700, Best length = 536.02
# Iter 33800, Best length = 536.02
# Iter 33900, Best length = 536.02
# Iter 34000, Best length = 536.02
# Iter 34100, Best length = 536.02
# Iter 34200, Best length = 536.02
# Iter 34300, Best length = 536.02
# Iter 34400, Best length = 536.02
# Iter 34500, Best length = 536.02
# Iter 34600, Best length = 536.02
# Iter 34700, Best length = 536.02
# Iter 34800, Best length = 536.02
# Iter 34900, Best length = 536.02
# Iter 35000, Best length = 536.02
# Iter 35100, Best length = 536.02
# Iter 35200, Best length = 536.02
# Iter 35300, Best length = 536.02
# Iter 35400, Best length = 536.02
# Iter 35500, Best length = 536.02
# Iter 35600, Best length = 536.02
# Iter 35700, Best length = 536.02
# Iter 35800, Best length = 536.02
# Iter 35900, Best length = 536.02
# Iter 36000, Best length = 536.02
# Iter 36100, Best length = 536.02
# Iter 36200, Best length = 536.02
# Iter 36300, Best length = 536.02
# Iter 36400, Best length = 536.02
# Iter 36500, Best length = 536.02
# Iter 36600, Best length = 536.02
# Iter 36700, Best length = 536.02
# Iter 36800, Best length = 536.02
# Iter 36900, Best length = 536.02
# Iter 37000, Best length = 536.02
# Iter 37100, Best length = 536.02
# Iter 37200, Best length = 536.02
# Iter 37300, Best length = 536.02
# Iter 37400, Best length = 536.02
# Iter 37500, Best length = 536.02
# Iter 37600, Best length = 536.02
# Iter 37700, Best length = 536.02
# Iter 37800, Best length = 536.02
# Iter 37900, Best length = 536.02
# Iter 38000, Best length = 536.02
# Iter 38100, Best length = 536.02
# Iter 38200, Best length = 536.02
# Iter 38300, Best length = 536.02
# Iter 38400, Best length = 536.02
# Iter 38500, Best length = 536.02
# Iter 38600, Best length = 536.02
# Iter 38700, Best length = 536.02
# Iter 38800, Best length = 536.02
# Iter 38900, Best length = 536.02
# Iter 39000, Best length = 536.02
# Iter 39100, Best length = 536.02
# Iter 39200, Best length = 536.02
# Iter 39300, Best length = 536.02
# Iter 39400, Best length = 536.02
# Iter 39500, Best length = 536.02
# Iter 39600, Best length = 536.02
# Iter 39700, Best length = 536.02
# Iter 39800, Best length = 536.02
# Iter 39900, Best length = 536.02
# Iter 40000, Best length = 536.02
# Iter 40100, Best length = 536.02
# Iter 40200, Best length = 536.02
# Iter 40300, Best length = 536.02
# Iter 40400, Best length = 536.02
# Iter 40500, Best length = 536.02
# Iter 40600, Best length = 536.02
# Iter 40700, Best length = 536.02
# Iter 40800, Best length = 536.02
# Iter 40900, Best length = 536.02
# Iter 41000, Best length = 536.02
# Iter 41100, Best length = 536.02
# Iter 41200, Best length = 536.02
# Iter 41300, Best length = 536.02
# Iter 41400, Best length = 536.02
# Iter 41500, Best length = 536.02
# Iter 41600, Best length = 536.02
# Iter 41700, Best length = 536.02
# Iter 41800, Best length = 536.02
# Iter 41900, Best length = 536.02
# Iter 42000, Best length = 536.02
# Iter 42100, Best length = 536.02
# Iter 42200, Best length = 536.02
# Iter 42300, Best length = 536.02
# Iter 42400, Best length = 536.02
# Iter 42500, Best length = 536.02
# Iter 42600, Best length = 536.02
# Iter 42700, Best length = 536.02
# Iter 42800, Best length = 536.02
# Iter 42900, Best length = 536.02
# Iter 43000, Best length = 536.02
# Iter 43100, Best length = 536.02
# Iter 43200, Best length = 536.02
# Iter 43300, Best length = 536.02
# Iter 43400, Best length = 536.02
# Iter 43500, Best length = 536.02
# Iter 43600, Best length = 536.02
# Iter 43700, Best length = 536.02
# Iter 43800, Best length = 536.02
# Iter 43900, Best length = 536.02
# Iter 44000, Best length = 536.02
# Iter 44100, Best length = 536.02
# Iter 44200, Best length = 536.02
# Iter 44300, Best length = 536.02
# Iter 44400, Best length = 536.02
# Iter 44500, Best length = 536.02
# Iter 44600, Best length = 536.02
# Iter 44700, Best length = 536.02
# Iter 44800, Best length = 536.02
# Iter 44900, Best length = 536.02
# Iter 45000, Best length = 536.02
# Iter 45100, Best length = 536.02
# Iter 45200, Best length = 536.02
# Iter 45300, Best length = 536.02
# Iter 45400, Best length = 536.02
# Iter 45500, Best length = 536.02
# Iter 45600, Best length = 536.02
# Iter 45700, Best length = 536.02
# Iter 45800, Best length = 536.02
# Iter 45900, Best length = 536.02
# Iter 46000, Best length = 536.02
# Iter 46100, Best length = 536.02
# Iter 46200, Best length = 536.02
# Iter 46300, Best length = 536.02
# Iter 46400, Best length = 536.02
# Iter 46500, Best length = 536.02
# Iter 46600, Best length = 536.02
# Iter 46700, Best length = 536.02
# Iter 46800, Best length = 536.02
# Iter 46900, Best length = 536.02
# Iter 47000, Best length = 536.02
# Iter 47100, Best length = 536.02
# Iter 47200, Best length = 536.02
# Iter 47300, Best length = 536.02
# Iter 47400, Best length = 536.02
# Iter 47500, Best length = 536.02
# Iter 47600, Best length = 536.02
# Iter 47700, Best length = 536.02
# Iter 47800, Best length = 536.02
# Iter 47900, Best length = 536.02
# Iter 48000, Best length = 536.02
# Iter 48100, Best length = 536.02
# Iter 48200, Best length = 536.02
# Iter 48300, Best length = 536.02
# Iter 48400, Best length = 536.02
# Iter 48500, Best length = 536.02
# Iter 48600, Best length = 536.02
# Iter 48700, Best length = 536.02
# Iter 48800, Best length = 536.02
# Iter 48900, Best length = 536.02
# Iter 49000, Best length = 536.02
# Iter 49100, Best length = 536.02
# Iter 49200, Best length = 536.02
# Iter 49300, Best length = 536.02
# Iter 49400, Best length = 536.02
# Iter 49500, Best length = 536.02
# Iter 49600, Best length = 536.02
# Iter 49700, Best length = 536.02
# Iter 49800, Best length = 536.02
# Iter 49900, Best length = 536.02
# Iter 50000, Best length = 536.02
# Iter 50100, Best length = 536.02
# Iter 50200, Best length = 536.02
# Iter 50300, Best length = 536.02
# Iter 50400, Best length = 536.02
# Iter 50500, Best length = 536.02
# Iter 50600, Best length = 536.02
# Iter 50700, Best length = 536.02
# Iter 50800, Best length = 536.02
# Iter 50900, Best length = 536.02
# Iter 51000, Best length = 536.02
# Iter 51100, Best length = 536.02
# Iter 51200, Best length = 536.02
# Iter 51300, Best length = 536.02
# Iter 51400, Best length = 536.02
# Iter 51500, Best length = 536.02
# Iter 51600, Best length = 536.02
# Iter 51700, Best length = 536.02
# Iter 51800, Best length = 536.02
# Iter 51900, Best length = 536.02
# Iter 52000, Best length = 536.02
# Iter 52100, Best length = 536.02
# Iter 52200, Best length = 536.02
# Iter 52300, Best length = 536.02
# Iter 52400, Best length = 536.02
# Iter 52500, Best length = 536.02
# Iter 52600, Best length = 536.02
# Iter 52700, Best length = 536.02
# Iter 52800, Best length = 536.02
# Iter 52900, Best length = 536.02
# Iter 53000, Best length = 536.02
# Iter 53100, Best length = 536.02
# Iter 53200, Best length = 536.02
# Iter 53300, Best length = 536.02
# Iter 53400, Best length = 536.02
# Iter 53500, Best length = 536.02
# Iter 53600, Best length = 536.02
# Iter 53700, Best length = 536.02
# Iter 53800, Best length = 536.02
# Iter 53900, Best length = 536.02
# Iter 54000, Best length = 536.02
# Iter 54100, Best length = 536.02
# Iter 54200, Best length = 536.02
# Iter 54300, Best length = 536.02
# Iter 54400, Best length = 536.02
# Iter 54500, Best length = 536.02
# Iter 54600, Best length = 536.02
# Iter 54700, Best length = 536.02
# Iter 54800, Best length = 536.02
# Iter 54900, Best length = 536.02
# Iter 55000, Best length = 536.02
# Iter 55100, Best length = 536.02
# Iter 55200, Best length = 536.02
# Iter 55300, Best length = 536.02
# Iter 55400, Best length = 536.02
# Iter 55500, Best length = 536.02
# Iter 55600, Best length = 536.02
# Iter 55700, Best length = 536.02
# Iter 55800, Best length = 536.02
# Iter 55900, Best length = 536.02
# Iter 56000, Best length = 536.02
# Iter 56100, Best length = 536.02
# Iter 56200, Best length = 536.02
# Iter 56300, Best length = 536.02
# Iter 56400, Best length = 536.02
# Iter 56500, Best length = 536.02
# Iter 56600, Best length = 536.02
# Iter 56700, Best length = 536.02
# Iter 56800, Best length = 536.02
# Iter 56900, Best length = 536.02
# Iter 57000, Best length = 536.02
# Iter 57100, Best length = 536.02
# Iter 57200, Best length = 536.02
# Iter 57300, Best length = 536.02
# Iter 57400, Best length = 536.02
# Iter 57500, Best length = 536.02
# Iter 57600, Best length = 536.02
# Iter 57700, Best length = 536.02
# Iter 57800, Best length = 536.02
# Iter 57900, Best length = 536.02
# Iter 58000, Best length = 536.02
# Iter 58100, Best length = 536.02
# Iter 58200, Best length = 536.02
# Iter 58300, Best length = 536.02
# Iter 58400, Best length = 536.02
# Iter 58500, Best length = 536.02
# Iter 58600, Best length = 536.02
# Iter 58700, Best length = 536.02
# Iter 58800, Best length = 536.02
# Iter 58900, Best length = 536.02
# Iter 59000, Best length = 536.02
# Iter 59100, Best length = 536.02
# Iter 59200, Best length = 536.02
# Iter 59300, Best length = 536.02
# Iter 59400, Best length = 536.02
# Iter 59500, Best length = 536.02
# Iter 59600, Best length = 536.02
# Iter 59700, Best length = 536.02
# Iter 59800, Best length = 536.02
# Iter 59900, Best length = 536.02
# Iter 60000, Best length = 536.02
# Iter 60100, Best length = 536.02
# Iter 60200, Best length = 536.02
# Iter 60300, Best length = 536.02
# Iter 60400, Best length = 536.02
# Iter 60500, Best length = 536.02
# Iter 60600, Best length = 536.02
# Iter 60700, Best length = 536.02
# Iter 60800, Best length = 536.02
# Iter 60900, Best length = 536.02
# Iter 61000, Best length = 536.02
# Iter 61100, Best length = 536.02
# Iter 61200, Best length = 536.02
# Iter 61300, Best length = 536.02
# Iter 61400, Best length = 536.02
# Iter 61500, Best length = 536.02
# Iter 61600, Best length = 536.02
# Iter 61700, Best length = 536.02
# Iter 61800, Best length = 536.02
# Iter 61900, Best length = 536.02
# Iter 62000, Best length = 536.02
# Iter 62100, Best length = 536.02
# Iter 62200, Best length = 536.02
# Iter 62300, Best length = 536.02
# Iter 62400, Best length = 536.02
# Iter 62500, Best length = 536.02
# Iter 62600, Best length = 536.02
# Iter 62700, Best length = 536.02
# Iter 62800, Best length = 536.02
# Iter 62900, Best length = 536.02
# Iter 63000, Best length = 536.02
# Iter 63100, Best length = 536.02
# Iter 63200, Best length = 536.02
# Iter 63300, Best length = 536.02
# Iter 63400, Best length = 536.02
# Iter 63500, Best length = 536.02
# Iter 63600, Best length = 536.02
# Iter 63700, Best length = 536.02
# Iter 63800, Best length = 536.02
# Iter 63900, Best length = 536.02
# Iter 64000, Best length = 536.02
# Iter 64100, Best length = 536.02
# Iter 64200, Best length = 536.02
# Iter 64300, Best length = 536.02
# Iter 64400, Best length = 536.02
# Iter 64500, Best length = 536.02
# Iter 64600, Best length = 536.02
# Iter 64700, Best length = 536.02
# Iter 64800, Best length = 536.02
# Iter 64900, Best length = 536.02
# Iter 65000, Best length = 536.02
# Iter 65100, Best length = 536.02
# Iter 65200, Best length = 536.02
# Iter 65300, Best length = 536.02
# Iter 65400, Best length = 536.02
# Iter 65500, Best length = 536.02
# Iter 65600, Best length = 536.02
# Iter 65700, Best length = 536.02
# Iter 65800, Best length = 536.02
# Iter 65900, Best length = 536.02
# Iter 66000, Best length = 536.02
# Iter 66100, Best length = 536.02
# Iter 66200, Best length = 536.02
# Iter 66300, Best length = 536.02
# Iter 66400, Best length = 536.02
# Iter 66500, Best length = 536.02
# Iter 66600, Best length = 536.02
# Iter 66700, Best length = 536.02
# Iter 66800, Best length = 536.02
# Iter 66900, Best length = 536.02
# Iter 67000, Best length = 536.02
# Iter 67100, Best length = 536.02
# Iter 67200, Best length = 536.02
# Iter 67300, Best length = 536.02
# Iter 67400, Best length = 536.02
# Iter 67500, Best length = 536.02
# Iter 67600, Best length = 536.02
# Iter 67700, Best length = 536.02
# Iter 67800, Best length = 536.02
# Iter 67900, Best length = 536.02
# Iter 68000, Best length = 536.02
# Iter 68100, Best length = 536.02
# Iter 68200, Best length = 536.02
# Iter 68300, Best length = 536.02
# Iter 68400, Best length = 536.02
# Iter 68500, Best length = 536.02
# Iter 68600, Best length = 536.02
# Iter 68700, Best length = 536.02
# Iter 68800, Best length = 536.02
# Iter 68900, Best length = 536.02
# Iter 69000, Best length = 536.02
# Iter 69100, Best length = 536.02
# Iter 69200, Best length = 536.02
# Iter 69300, Best length = 536.02
# Iter 69400, Best length = 536.02
# Iter 69500, Best length = 536.02
# Iter 69600, Best length = 536.02
# Iter 69700, Best length = 536.02
# Iter 69800, Best length = 536.02
# Iter 69900, Best length = 536.02
# Iter 70000, Best length = 536.02
# Iter 70100, Best length = 536.02
# Iter 70200, Best length = 536.02
# Iter 70300, Best length = 536.02
# Iter 70400, Best length = 536.02
# Iter 70500, Best length = 536.02
# Iter 70600, Best length = 536.02
# Iter 70700, Best length = 536.02
# Iter 70800, Best length = 536.02
# Iter 70900, Best length = 536.02
# Iter 71000, Best length = 536.02
# Iter 71100, Best length = 536.02
# Iter 71200, Best length = 536.02
# Iter 71300, Best length = 536.02
# Iter 71400, Best length = 536.02
# Iter 71500, Best length = 536.02
# Iter 71600, Best length = 536.02
# Iter 71700, Best length = 536.02
# Iter 71800, Best length = 536.02
# Iter 71900, Best length = 536.02
# Iter 72000, Best length = 536.02
# Iter 72100, Best length = 536.02
# Iter 72200, Best length = 536.02
# Iter 72300, Best length = 536.02
# Iter 72400, Best length = 536.02
# Iter 72500, Best length = 536.02
# Iter 72600, Best length = 536.02
# Iter 72700, Best length = 536.02
# Iter 72800, Best length = 536.02
# Iter 72900, Best length = 536.02
# Iter 73000, Best length = 536.02
# Iter 73100, Best length = 536.02
# Iter 73200, Best length = 536.02
# Iter 73300, Best length = 536.02
# Iter 73400, Best length = 536.02
# Iter 73500, Best length = 536.02
# Iter 73600, Best length = 536.02
# Iter 73700, Best length = 536.02
# Iter 73800, Best length = 536.02
# Iter 73900, Best length = 536.02
# Iter 74000, Best length = 536.02
# Iter 74100, Best length = 536.02
# Iter 74200, Best length = 536.02
# Iter 74300, Best length = 536.02
# Iter 74400, Best length = 536.02
# Iter 74500, Best length = 536.02
# Iter 74600, Best length = 536.02
# Iter 74700, Best length = 536.02
# Iter 74800, Best length = 536.02
# Iter 74900, Best length = 536.02
# Iter 75000, Best length = 536.02
# Iter 75100, Best length = 536.02
# Iter 75200, Best length = 536.02
# Iter 75300, Best length = 536.02
# Iter 75400, Best length = 536.02
# Iter 75500, Best length = 536.02
# Iter 75600, Best length = 536.02
# Iter 75700, Best length = 536.02
# Iter 75800, Best length = 536.02
# Iter 75900, Best length = 536.02
# Iter 76000, Best length = 536.02
# Iter 76100, Best length = 536.02
# Iter 76200, Best length = 536.02
# Iter 76300, Best length = 536.02
# Iter 76400, Best length = 536.02
# Iter 76500, Best length = 536.02
# Iter 76600, Best length = 536.02
# Iter 76700, Best length = 536.02
# Iter 76800, Best length = 536.02
# Iter 76900, Best length = 536.02
# Iter 77000, Best length = 536.02
# Iter 77100, Best length = 536.02
# Iter 77200, Best length = 536.02
# Iter 77300, Best length = 536.02
# Iter 77400, Best length = 536.02
# Iter 77500, Best length = 536.02
# Iter 77600, Best length = 536.02
# Iter 77700, Best length = 536.02
# Iter 77800, Best length = 536.02
# Iter 77900, Best length = 536.02
# Iter 78000, Best length = 536.02
# Iter 78100, Best length = 536.02
# Iter 78200, Best length = 536.02
# Iter 78300, Best length = 536.02
# Iter 78400, Best length = 536.02
# Iter 78500, Best length = 536.02
# Iter 78600, Best length = 536.02
# Iter 78700, Best length = 536.02
# Iter 78800, Best length = 536.02
# Iter 78900, Best length = 536.02
# Iter 79000, Best length = 536.02
# Iter 79100, Best length = 536.02
# Iter 79200, Best length = 536.02
# Iter 79300, Best length = 536.02
# Iter 79400, Best length = 536.02
# Iter 79500, Best length = 536.02
# Iter 79600, Best length = 536.02
# Iter 79700, Best length = 536.02
# Iter 79800, Best length = 536.02
# Iter 79900, Best length = 536.02
# Iter 80000, Best length = 536.02
# Iter 80100, Best length = 536.02
# Iter 80200, Best length = 536.02
# Iter 80300, Best length = 536.02
# Iter 80400, Best length = 536.02
# Iter 80500, Best length = 536.02
# Iter 80600, Best length = 536.02
# Iter 80700, Best length = 536.02
# Iter 80800, Best length = 536.02
# Iter 80900, Best length = 536.02
# Iter 81000, Best length = 536.02
# Iter 81100, Best length = 536.02
# Iter 81200, Best length = 536.02
# Iter 81300, Best length = 536.02
# Iter 81400, Best length = 536.02
# Iter 81500, Best length = 536.02
# Iter 81600, Best length = 536.02
# Iter 81700, Best length = 536.02
# Iter 81800, Best length = 536.02
# Iter 81900, Best length = 536.02
# Iter 82000, Best length = 536.02
# Iter 82100, Best length = 536.02
# Iter 82200, Best length = 536.02
# Iter 82300, Best length = 536.02
# Iter 82400, Best length = 536.02
# Iter 82500, Best length = 536.02
# Iter 82600, Best length = 536.02
# Iter 82700, Best length = 536.02
# Iter 82800, Best length = 536.02
# Iter 82900, Best length = 536.02
# Iter 83000, Best length = 536.02
# Iter 83100, Best length = 536.02
# Iter 83200, Best length = 536.02
# Iter 83300, Best length = 536.02
# Iter 83400, Best length = 536.02
# Iter 83500, Best length = 536.02
# Iter 83600, Best length = 536.02
# Iter 83700, Best length = 536.02
# Iter 83800, Best length = 536.02
# Iter 83900, Best length = 536.02
# Iter 84000, Best length = 536.02
# Iter 84100, Best length = 536.02
# Iter 84200, Best length = 536.02
# Iter 84300, Best length = 536.02
# Iter 84400, Best length = 536.02
# Iter 84500, Best length = 536.02
# Iter 84600, Best length = 536.02
# Iter 84700, Best length = 536.02
# Iter 84800, Best length = 536.02
# Iter 84900, Best length = 536.02
# Iter 85000, Best length = 536.02
# Iter 85100, Best length = 536.02
# Iter 85200, Best length = 536.02
# Iter 85300, Best length = 536.02
# Iter 85400, Best length = 536.02
# Iter 85500, Best length = 536.02
# Iter 85600, Best length = 536.02
# Iter 85700, Best length = 536.02
# Iter 85800, Best length = 536.02
# Iter 85900, Best length = 536.02
# Iter 86000, Best length = 536.02
# Iter 86100, Best length = 536.02
# Iter 86200, Best length = 536.02
# Iter 86300, Best length = 536.02
# Iter 86400, Best length = 536.02
# Iter 86500, Best length = 536.02
# Iter 86600, Best length = 536.02
# Iter 86700, Best length = 536.02
# Iter 86800, Best length = 536.02
# Iter 86900, Best length = 536.02
# Iter 87000, Best length = 536.02
# Iter 87100, Best length = 536.02
# Iter 87200, Best length = 536.02
# Iter 87300, Best length = 536.02
# Iter 87400, Best length = 536.02
# Iter 87500, Best length = 536.02
# Iter 87600, Best length = 536.02
# Iter 87700, Best length = 536.02
# Iter 87800, Best length = 536.02
# Iter 87900, Best length = 536.02
# Iter 88000, Best length = 536.02
# Iter 88100, Best length = 536.02
# Iter 88200, Best length = 536.02
# Iter 88300, Best length = 536.02
# Iter 88400, Best length = 536.02
# Iter 88500, Best length = 536.02
# Iter 88600, Best length = 536.02
# Iter 88700, Best length = 536.02
# Iter 88800, Best length = 536.02
# Iter 88900, Best length = 536.02
# Iter 89000, Best length = 536.02
# Iter 89100, Best length = 536.02
# Iter 89200, Best length = 536.02
# Iter 89300, Best length = 536.02
# Iter 89400, Best length = 536.02
# Iter 89500, Best length = 536.02
# Iter 89600, Best length = 536.02
# Iter 89700, Best length = 536.02
# Iter 89800, Best length = 536.02
# Iter 89900, Best length = 536.02
# Iter 90000, Best length = 536.02
# Iter 90100, Best length = 536.02
# Iter 90200, Best length = 536.02
# Iter 90300, Best length = 536.02
# Iter 90400, Best length = 536.02
# Iter 90500, Best length = 536.02
# Iter 90600, Best length = 536.02
# Iter 90700, Best length = 536.02
# Iter 90800, Best length = 536.02
# Iter 90900, Best length = 536.02
# Iter 91000, Best length = 536.02
# Iter 91100, Best length = 536.02
# Iter 91200, Best length = 536.02
# Iter 91300, Best length = 536.02
# Iter 91400, Best length = 536.02
# Iter 91500, Best length = 536.02
# Iter 91600, Best length = 536.02
# Iter 91700, Best length = 536.02
# Iter 91800, Best length = 536.02
# Iter 91900, Best length = 536.02
# Iter 92000, Best length = 536.02
# Iter 92100, Best length = 536.02
# Iter 92200, Best length = 536.02
# Iter 92300, Best length = 536.02
# Iter 92400, Best length = 536.02
# Iter 92500, Best length = 536.02
# Iter 92600, Best length = 536.02
# Iter 92700, Best length = 536.02
# Iter 92800, Best length = 536.02
# Iter 92900, Best length = 536.02
# Iter 93000, Best length = 536.02
# Iter 93100, Best length = 536.02
# Iter 93200, Best length = 536.02
# Iter 93300, Best length = 536.02
# Iter 93400, Best length = 536.02
# Iter 93500, Best length = 536.02
# Iter 93600, Best length = 536.02
# Iter 93700, Best length = 536.02
# Iter 93800, Best length = 536.02
# Iter 93900, Best length = 536.02
# Iter 94000, Best length = 536.02
# Iter 94100, Best length = 536.02
# Iter 94200, Best length = 536.02
# Iter 94300, Best length = 536.02
# Iter 94400, Best length = 536.02
# Iter 94500, Best length = 536.02
# Iter 94600, Best length = 536.02
# Iter 94700, Best length = 536.02
# Iter 94800, Best length = 536.02
# Iter 94900, Best length = 536.02
# Iter 95000, Best length = 536.02
# Iter 95100, Best length = 536.02
# Iter 95200, Best length = 536.02
# Iter 95300, Best length = 536.02
# Iter 95400, Best length = 536.02
# Iter 95500, Best length = 536.02
# Iter 95600, Best length = 536.02
# Iter 95700, Best length = 536.02
# Iter 95800, Best length = 536.02
# Iter 95900, Best length = 536.02
# Iter 96000, Best length = 536.02
# Iter 96100, Best length = 536.02
# Iter 96200, Best length = 536.02
# Iter 96300, Best length = 536.02
# Iter 96400, Best length = 536.02
# Iter 96500, Best length = 536.02
# Iter 96600, Best length = 536.02
# Iter 96700, Best length = 536.02
# Iter 96800, Best length = 536.02
# Iter 96900, Best length = 536.02
# Iter 97000, Best length = 536.02
# Iter 97100, Best length = 536.02
# Iter 97200, Best length = 536.02
# Iter 97300, Best length = 536.02
# Iter 97400, Best length = 536.02
# Iter 97500, Best length = 536.02
# Iter 97600, Best length = 536.02
# Iter 97700, Best length = 536.02
# Iter 97800, Best length = 536.02
# Iter 97900, Best length = 536.02
# Iter 98000, Best length = 536.02
# Iter 98100, Best length = 536.02
# Iter 98200, Best length = 536.02
# Iter 98300, Best length = 536.02
# Iter 98400, Best length = 536.02
# Iter 98500, Best length = 536.02
# Iter 98600, Best length = 536.02
# Iter 98700, Best length = 536.02
# Iter 98800, Best length = 536.02
# Iter 98900, Best length = 536.02
# Iter 99000, Best length = 536.02
# Iter 99100, Best length = 536.02
# Iter 99200, Best length = 536.02
# Iter 99300, Best length = 536.02
# Iter 99400, Best length = 536.02
# Iter 99500, Best length = 536.02
# Iter 99600, Best length = 536.02
# Iter 99700, Best length = 536.02
# Iter 99800, Best length = 536.02
# Iter 99900, Best length = 536.02
# Best tour: [23, 3, 5, 2, 4, 21, 14, 11, 0, 12, 9, 29, 6, 27, 20, 18, 22, 25, 28, 19, 16, 7, 17, 1, 8, 10, 15, 13, 24, 26]
# Best length: 536.0210591729848
